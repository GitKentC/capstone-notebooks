# %%
import os
import imagehash
import random
import shutil
from PIL import Image
from pathlib import Path

# %%
""" GLOBAL VARIABLES """
DATA_DIR: Path = Path("C:/capstone/dataset/raw")
EXTENSIONS: list[str] = [".png", ".jpg", ".jpeg", ".bmp", ".gif"]

# %% [markdown]
# ## CHECK DUPLICATES FOR EACH CLASS

# %% [markdown]
# This only check duplicates for each class assuming you provide DATA_DIR path to a folder consisting subfolders, example:
# ```
# dataset
# ├───subfolder_1
# │   ├───class_1
# │   ├───...
# │   └───class_n
# └───subfolder_n
#     ├───class_1
#     ├─── ...
#     └───class_n
# ```
# This is tipically what's available on Kaggle

# %%
def print_log(duplicates_log: dict[str, list[tuple[str, str]]], 
                   total_duplicates: dict[str, int]) -> None:
    """Print duplicate images and counts per subfolder."""
    if duplicates_log:
        print("\nDuplicate images found:")
        for class_name, duplicate_pairs in duplicates_log.items():
            print(f"\nClass: {class_name}")
            for duplicate, original in duplicate_pairs:
                print(f"Duplicate: {duplicate} | Original: {original}")
        
        print("\nTotal duplicates found per subfolder:")
        for subfolder, count in total_duplicates.items():
            print(f"{subfolder}: {count}")
    else:
        print("No duplicates found in log; \
              Duplicates log not found")
    
def check_for_dupes(ds_dir: Path):
    """Check for duplicate images in the dataset."""
    duplicates_log: dict[str, list[tuple[str, str]]] = {}
    total_duplicates: dict[str, int] = {subfolder.name: 0 for subfolder \
                                        in ds_dir.iterdir() if subfolder.is_dir()}

    for subfolder in ds_dir.iterdir():
        """ Iterate through subfolders (1st layer) """
        subfolder_path: Path = ds_dir / subfolder.name
        print(f"In subfolder {subfolder}:")
        
        for class_folder in subfolder_path.iterdir():
            """ Iterate through class folders (2nd layer) """
            if class_folder.is_dir():
                print(f"Processing {class_folder.name}")
                
                hashes: dict[str, str] = {} # initialize to store hashes for each class
                
                for image_file in class_folder.iterdir():
                    """ Iterate through image files (3rd; last layer) """
                    if image_file.suffix.lower() in EXTENSIONS:
                        try:
                            with Image.open(image_file) as img:
                                img_hash = imagehash.phash(img) # calculate hash based on perceptual hash
                            
                            if img_hash in hashes: # add duplicates in each class to log
                                duplicates_log.setdefault(class_folder.name, []) \
                                .append((str(image_file), hashes[img_hash]))

                                total_duplicates[subfolder.name] += 1  # Increment total duplicate count
                            else: # add new unique image to hashes
                                hashes[img_hash] = str(image_file)
                        except Exception as e:
                            print(f"Error processing {image_file}: {e}")
    print_log(duplicates_log, total_duplicates)

# %%
check_for_dupes(DATA_DIR)
# Out:
# In subfolder C:\capstone\dataset\raw\images_default:
# Processing aerosol_cans
# Processing aluminum_food_cans
# Processing aluminum_soda_cans
# Processing cardboard_boxes
# Processing cardboard_packaging
# Processing clothing
# Processing coffee_grounds
# Processing disposable_plastic_cutlery
# Processing eggshells
# Processing food_waste
# Processing glass_beverage_bottles
# Processing glass_cosmetic_containers
# Processing glass_food_jars
# Processing magazines
# Processing newspaper
# Processing office_paper
# Processing paper_cups
# Processing plastic_cup_lids
# Processing plastic_detergent_bottles
# Processing plastic_food_containers
# Processing plastic_shopping_bags
# Processing plastic_soda_bottles
# Processing plastic_straws
# Processing plastic_trash_bags
# Processing plastic_water_bottles
# Processing shoes
# Processing steel_food_cans
# Processing styrofoam_cups
# Processing styrofoam_food_containers
# Processing tea_bags
# In subfolder C:\capstone\dataset\raw\images_real:
# Processing aerosol_cans
# Processing aluminum_food_cans
# Processing aluminum_soda_cans
# Processing cardboard_boxes
# Processing cardboard_packaging
# Processing clothing
# Processing coffee_grounds
# Processing disposable_plastic_cutlery
# Processing eggshells
# Processing food_waste
# Processing glass_beverage_bottles
# Processing glass_cosmetic_containers
# Processing glass_food_jars
# Processing magazines
# Processing newspaper
# Processing office_paper
# Processing paper_cups
# Processing plastic_cup_lids
# Processing plastic_detergent_bottles
# Processing plastic_food_containers
# Processing plastic_shopping_bags
# Processing plastic_soda_bottles
# Processing plastic_straws
# Processing plastic_trash_bags
# Processing plastic_water_bottles
# Processing shoes
# Processing steel_food_cans
# Processing styrofoam_cups
# Processing styrofoam_food_containers
# Processing tea_bags
#
# Duplicate images found:
#
# Class: aerosol_cans
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_113.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_100.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_144.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_127.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_149.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_133.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_185.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_176.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_196.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_164.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_20.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_163.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_200.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_198.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_211.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_125.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_214.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_105.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_248.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_229.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_31.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_159.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_35.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_101.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_36.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_32.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_4.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_34.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_49.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_100.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_5.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_45.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_50.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_226.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_58.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_41.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_6.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_229.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_61.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_1.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_62.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_160.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_65.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_34.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_66.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_34.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_67.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_46.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_69.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_42.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_73.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_27.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_74.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_1.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_75.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_169.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_78.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_34.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_8.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_100.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_80.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_3.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_84.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_103.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_85.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_2.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_90.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_111.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_91.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_177.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_93.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_169.png
# Duplicate: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_98.png | Original: C:\capstone\dataset\raw\images_default\aerosol_cans\Image_53.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_112.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_1.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_118.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_113.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_123.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_11.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_144.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_114.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_16.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_139.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_162.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_159.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_179.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_121.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_18.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_114.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_183.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_149.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_190.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_117.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_191.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_120.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_198.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_168.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_199.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_150.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_200.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_147.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_208.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_141.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_213.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_206.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_218.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_149.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_235.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_148.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_249.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_220.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_26.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_181.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_32.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_100.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_36.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_237.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_41.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_153.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_42.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_140.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_47.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_2.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_48.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_161.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_50.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_137.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_51.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_237.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_53.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_23.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_55.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_124.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_67.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_159.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_68.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_114.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_69.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_2.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_71.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_106.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_77.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_15.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_81.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_52.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_83.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_25.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_88.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_189.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_9.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_44.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_93.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_158.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_94.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_140.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_95.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_245.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_96.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_114.png
# Duplicate: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_98.png | Original: C:\capstone\dataset\raw\images_real\aerosol_cans\Image_116.png
#
# Class: aluminum_food_cans
# Duplicate: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_193.png | Original: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_111.png
# Duplicate: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_22.png | Original: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_200.png
# Duplicate: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_228.png | Original: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_141.png
# Duplicate: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_229.png | Original: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_165.png
# Duplicate: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_23.png | Original: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_104.png
# Duplicate: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_238.png | Original: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_196.png
# Duplicate: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_243.png | Original: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_208.png
# Duplicate: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_245.png | Original: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_223.png
# Duplicate: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_248.png | Original: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_119.png
# Duplicate: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_250.png | Original: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_103.png
# Duplicate: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_35.png | Original: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_103.png
# Duplicate: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_46.png | Original: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_12.png
# Duplicate: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_51.png | Original: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_125.png
# Duplicate: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_52.png | Original: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_208.png
# Duplicate: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_53.png | Original: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_44.png
# Duplicate: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_54.png | Original: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_14.png
# Duplicate: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_62.png | Original: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_12.png
# Duplicate: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_67.png | Original: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_103.png
# Duplicate: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_70.png | Original: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_15.png
# Duplicate: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_73.png | Original: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_137.png
# Duplicate: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_75.png | Original: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image_13.png
# Duplicate: C:\capstone\dataset\raw\images_default\aluminum_food_cans\Image
def delete_dupes(ds_dir: Path) -> None:
    """Check for duplicate images in the dataset."""
    duplicates_log: dict[str, list[tuple[str, str]]] = {}
    total_duplicates: dict[str, int] = {subfolder.name: 0 for subfolder \
                                        in ds_dir.iterdir() if subfolder.is_dir()}

    for subfolder in ds_dir.iterdir():
        """ Iterate through subfolders (1st layer) """
        subfolder_path: Path = ds_dir / subfolder.name
        cleaned_sub_path: Path = ds_dir.parent / 'dupe_cleaned' / subfolder.name

        print(f"In subfolder {subfolder}:")
        
        for class_folder in subfolder_path.iterdir():
            """ Iterate through class folders (2nd layer) """
            if class_folder.is_dir():
                print(f"Processing {class_folder.name}")

                cleaned_class_path: Path = cleaned_sub_path / class_folder.name
                if not Path.exists(cleaned_class_path): # make dir for dupe-cleaned ds
                    cleaned_class_path.mkdir(parents=True, exist_ok=False)
                
                hashes: dict[str, str] = {} # initialize to store hashes for each class
                
                for image_file in class_folder.iterdir():
                    """ Iterate through image files (3rd; last layer) """
                    if image_file.suffix.lower() in EXTENSIONS:
                        try:
                            with Image.open(image_file) as img:
                                img_hash = imagehash.phash(img) # calculate hash based on perceptual hash
                            
                            if img_hash not in hashes: #skip copy if in hash (duplicate)
                                destination = cleaned_class_path / image_file.name
                                copy_if_not_exist(image_file, destination)
                                hashes[img_hash] = str(image_file)

                        except Exception as e:
                            print(f"Error processing {image_file}: {e}")

# %%
delete_dupes(DATA_DIR)
# Out:
# In subfolder C:\capstone\dataset\raw\images_default:
# Processing aerosol_cans
# Processing aluminum_food_cans
# Processing aluminum_soda_cans
# Processing cardboard_boxes
# Processing cardboard_packaging
# Processing clothing
# Processing coffee_grounds
# Processing disposable_plastic_cutlery
# Processing eggshells
# Processing food_waste
# Processing glass_beverage_bottles
# Processing glass_cosmetic_containers
# Processing glass_food_jars
# Processing magazines
# Processing newspaper
# Processing office_paper
# Processing paper_cups
# Processing plastic_cup_lids
# Processing plastic_detergent_bottles
# Processing plastic_food_containers
# Processing plastic_shopping_bags
# Processing plastic_soda_bottles
# Processing plastic_straws
# Processing plastic_trash_bags
# Processing plastic_water_bottles
# Processing shoes
# Processing steel_food_cans
# Processing styrofoam_cups
# Processing styrofoam_food_containers
# Processing tea_bags
# In subfolder C:\capstone\dataset\raw\images_real:
# Processing aerosol_cans
# Processing aluminum_food_cans
# Processing aluminum_soda_cans
# Processing cardboard_boxes
# Processing cardboard_packaging
# Processing clothing
# Processing coffee_grounds
# Processing disposable_plastic_cutlery
# Processing eggshells
# Processing food_waste
# Processing glass_beverage_bottles
# Processing glass_cosmetic_containers
# Processing glass_food_jars
# Processing magazines
# Processing newspaper
# Processing office_paper
# Processing paper_cups
# Processing plastic_cup_lids
# Processing plastic_detergent_bottles
# Processing plastic_food_containers
# Processing plastic_shopping_bags
# Processing plastic_soda_bottles
# Processing plastic_straws
# Processing plastic_trash_bags
# Processing plastic_water_bottles
# Processing shoes
# Processing steel_food_cans
# Processing styrofoam_cups
# Processing styrofoam_food_containers
# Processing tea_bags

# %% [markdown]
# ## SPLIT DATASET INTO (TRAIN, VALIDATION AND TEST)
#
# * **WIP: STILL EXPERIMENTAL**

# %% [markdown]
# **ONLY USE THIS CODE IF YOU WANT YOUR DATASET LOOKS LIKE:** <br>
# ```
# dataset
# ├───subfolder_1
# │   ├───train
# │   ├───test
# │   └───validation
# └───subfolder_n
#     ├───train
#     ├───test
#     └───validation
# ```
# **Note:** Classes inside your splitted dataset will remain the same <br>
# Example: `dataset/subfolder/train/class_n`

# %%
""" GLOBAL VARIABLES FOR SPLITTING """
CLEAN_DS_DIR: Path = DATA_DIR.parent / 'dupe_cleaned'
SPLIT_RATIOS: dict[str, float] = {'train': 0.7, 'validation': 0.2, 'test': 0.1}

# %%
def copy_if_not_exist(source: Path, destination: Path) -> None:
    if not Path.exists(destination):
        shutil.copy2(source, destination)

def split_files(files: list[Path]) -> dict[str, list[Path]]:
    """ This function splits the dataset using the list index """
    random.seed(42)
    random.shuffle(files)
    train_i_end: int = int(len(files) * SPLIT_RATIOS['train'])
    val_i_end: int = train_i_end + int(len(files) * SPLIT_RATIOS['validation'])
    return {
        'train': files[:train_i_end],
        'validation': files[train_i_end:val_i_end],
        'test': files[val_i_end:]
    }

def split_dataset(clean_ds_dir: Path) -> None:
    for subfolder in clean_ds_dir.iterdir():
        """ Iterate through subfolders (1st layer) """
        subfolder_path: Path = CLEAN_DS_DIR / subfolder.name
        split_path: Path = CLEAN_DS_DIR.parent / 'split'

        print(f"In subfolder {subfolder}:")
        for class_folder in subfolder_path.iterdir():
            """ Iterate through class folders (2nd layer) """
            if class_folder.is_dir():
                print(f"Processing {class_folder.name}")
                
                files = [ file for file in class_folder.iterdir() # iterate through files in 
                         if file.suffix.lower() in EXTENSIONS ]   # class folders;
                files = split_files(files)                        # store and split files
                
                for split, files in files.items():
                    destination_path: Path = split_path / subfolder.name / split /class_folder.name
                    if not Path.exists(destination_path):
                        destination_path.mkdir(parents=True, exist_ok=False)
                    for file_path in files:
                        destination = destination_path / file_path.name
                        copy_if_not_exist(file_path, destination)

# %%
split_dataset(CLEAN_DS_DIR)
# Out:
# In subfolder C:\capstone\dataset\dupe_cleaned\images_default:
# Processing aerosol_cans
# Processing aluminum_food_cans
# Processing aluminum_soda_cans
# Processing cardboard_boxes
# Processing cardboard_packaging
# Processing clothing
# Processing coffee_grounds
# Processing disposable_plastic_cutlery
# Processing eggshells
# Processing food_waste
# Processing glass_beverage_bottles
# Processing glass_cosmetic_containers
# Processing glass_food_jars
# Processing magazines
# Processing newspaper
# Processing office_paper
# Processing paper_cups
# Processing plastic_cup_lids
# Processing plastic_detergent_bottles
# Processing plastic_food_containers
# Processing plastic_shopping_bags
# Processing plastic_soda_bottles
# Processing plastic_straws
# Processing plastic_trash_bags
# Processing plastic_water_bottles
# Processing shoes
# Processing steel_food_cans
# Processing styrofoam_cups
# Processing styrofoam_food_containers
# Processing tea_bags
# In subfolder C:\capstone\dataset\dupe_cleaned\images_real:
# Processing aerosol_cans
# Processing aluminum_food_cans
# Processing aluminum_soda_cans
# Processing cardboard_boxes
# Processing cardboard_packaging
# Processing clothing
# Processing coffee_grounds
# Processing disposable_plastic_cutlery
# Processing eggshells
# Processing food_waste
# Processing glass_beverage_bottles
# Processing glass_cosmetic_containers
# Processing glass_food_jars
# Processing magazines
# Processing newspaper
# Processing office_paper
# Processing paper_cups
# Processing plastic_cup_lids
# Processing plastic_detergent_bottles
# Processing plastic_food_containers
# Processing plastic_shopping_bags
# Processing plastic_soda_bottles
# Processing plastic_straws
# Processing plastic_trash_bags
# Processing plastic_water_bottles
# Processing shoes
# Processing steel_food_cans
# Processing styrofoam_cups
# Processing styrofoam_food_containers
# Processing tea_bags

# %% [markdown]
# # CHECK TRAIN, TEST, VALIDATION FOR DUPES
# * **WIP: STILL EXPERIMENTAL**
# * **MANUAL**

# %%
def check_for_data_leakage():
    # Dictionary to store image hashes and their associated file paths and dataset type
    hash_dict = {}
    # Dictionary to store leaks found between datasets
    data_leakage_log = {subfolder: [] for subfolder in SUB_DIRS}

    # Iterate through each folder in train, validation, and test
    for subfolder in SUB_DIRS:
        subfolder_path = DATA_DIR / subfolder
        print(f"Checking for data leakage in '{subfolder}' set...")

        # Iterate through each class folder
        for class_folder in subfolder_path.iterdir():
            if class_folder.is_dir():
                # Iterate through images in the class folder
                for image_file in class_folder.iterdir():
                    if image_file.suffix.lower() in EXTENSIONS:
                        try:
                            # Open image and calculate hash
                            with Image.open(image_file) as img:
                                img_hash = imagehash.phash(img)

                            # Check if this hash already exists in another dataset
                            if img_hash in hash_dict:
                                # Check if it came from a different subset
                                if hash_dict[img_hash]['subfolder'] != subfolder:
                                    data_leakage_log[subfolder].append((image_file, hash_dict[img_hash]['path']))
                                    print(f"Duplicates: {image_file} (in '{subfolder}') | {hash_dict[img_hash]['path']} (in '{hash_dict[img_hash]['subfolder']}')")
                            else:
                                # If the hash is unique so far, store it with the file path and subfolder
                                hash_dict[img_hash] = {'path': image_file, 'subfolder': subfolder}
                        except Exception as e:
                            print(f"Error processing {image_file}: {e}")

    # # Output data leakage log if any leaks are found
    # if any(data_leakage_log[subfolder] for subfolder in SUB_DIRS):
    #     print("\nData leakage detected across datasets:")
    #     for subfolder, leakage_pairs in data_leakage_log.items():
    #         if leakage_pairs:
    #             print(f"\nLeakage in '{subfolder}' set:")
    #             for duplicate, original in leakage_pairs:
    #                 print(f"Duplicate in {duplicate} matches with {original}")
    # else:
    #     print("No data leakage found between train, validation, and test sets.")

# Execute the function
check_for_data_leakage()
# Out:
# Checking for data leakage in 'test' set...
# Checking for data leakage in 'train' set...
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\aluminum_food_cans\Image_103.png (in 'train') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\steel_food_cans\Image_113.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\aluminum_food_cans\Image_115.png (in 'train') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test\steel_food_cans\Image_104.png (in 'test')
# Duplicates: C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\train\aluminum_food_cans\Image_6.png (in 'train') | C:\Users\Keny\Downloads\virtualenv\dataset\cleaned\images_default_dupe_cleaned_set\test